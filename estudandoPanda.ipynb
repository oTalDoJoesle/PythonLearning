# %%
import pandas as pd
import numpy as np
df = pd.read_csv('df_ResultadosSeleções/results.csv')

# %%
df
# Out:
#              date home_team away_team  home_score  away_score tournament  \
# 0      1872-11-30  Scotland   England         0.0         0.0   Friendly
# 1      1873-03-08   England  Scotland         4.0         2.0   Friendly
# 2      1874-03-07  Scotland   England         2.0         1.0   Friendly
# 3      1875-03-06   England  Scotland         2.0         2.0   Friendly
# 4      1876-03-04  Scotland   England         3.0         0.0   Friendly
# ...           ...       ...       ...         ...         ...        ...
# 47121  2024-07-06       NaN       NaN         NaN         NaN  UEFA Euro
# 47122  2024-07-06       NaN       NaN         NaN         NaN  UEFA Euro
# 47123  2024-07-09       NaN       NaN         NaN         NaN  UEFA Euro
# 47124  2024-07-10       NaN       NaN         NaN         NaN  UEFA Euro
# 47125  2024-07-14       NaN       NaN         NaN         NaN  UEFA Euro
#
#              city   country  neutral
# 0         Glasgow  Scotland    False
# ...

# %%
## BRdf = (df['home_team'] == "Brazil")
## df[BRdf]
# Out:
#              date home_team  away_team  home_score  away_score  \
# 465    1916-07-08    Brazil      Chile         1.0         1.0
# 468    1916-07-12    Brazil    Uruguay         1.0         2.0
# 504    1917-10-12    Brazil      Chile         5.0         0.0
# 531    1919-05-11    Brazil      Chile         6.0         0.0
# 539    1919-05-18    Brazil  Argentina         3.0         1.0
# ...           ...       ...        ...         ...         ...
# 46011  2023-06-17    Brazil     Guinea         4.0         1.0
# 46075  2023-06-20    Brazil    Senegal         2.0         4.0
# 46272  2023-09-08    Brazil    Bolivia         5.0         1.0
# 46403  2023-10-12    Brazil  Venezuela         1.0         1.0
# 46710  2023-11-21    Brazil  Argentina         0.0         1.0
#
#                          tournament            city    country  neutral
# 465                    Copa América    Buenos Aires  Argentina     True
# ...

# %%
dfbr = df.loc[((df['home_team'] == "Brazil")|(df['away_team'] == "Brazil"))]

# %%
df['Winner'] = np.where(
    df['home_score']>df['away_score'],
    df['home_team'],
    np.where(
        df['home_score']<df['away_score'],
        df['away_team'],
        "empate")
)

# %%
dfbr
# Out:
#              date  home_team  away_team  home_score  away_score  \
# 432    1914-09-20  Argentina     Brazil         3.0         0.0
# 433    1914-09-27  Argentina     Brazil         0.0         1.0
# 465    1916-07-08     Brazil      Chile         1.0         1.0
# 466    1916-07-10  Argentina     Brazil         1.0         1.0
# 468    1916-07-12     Brazil    Uruguay         1.0         2.0
# ...           ...        ...        ...         ...         ...
# 46519  2023-10-17    Uruguay     Brazil         2.0         0.0
# 46577  2023-11-16   Colombia     Brazil         2.0         1.0
# 46710  2023-11-21     Brazil  Argentina         0.0         1.0
# 46999  2024-03-23    England     Brazil         0.0         1.0
# 47073  2024-03-26      Spain     Brazil         3.0         3.0
#
#                          tournament            city    country  neutral  \
# 432                        Friendly    Buenos Aires  Argentina    False
# ...

# %%
df.loc[
    df['Winner'] == "Brazil"
].count()
# Out:
# date          660
# home_team     660
# away_team     660
# home_score    660
# away_score    660
# tournament    660
# city          660
# country       660
# neutral       660
# Winner        660
# dtype: int64

# %%
#pd.set_option('display.max_rows', None)
#df['Winner'].value_counts().get("North Korea")
df.loc[
    (df['Winner'] == "North Korea") &
    ((df['home_team'] == "South Korea")|(df['away_team'] == "South Korea"))
]
# Out:
#              date    home_team    away_team  home_score  away_score  \
# 17467  1990-10-11  North Korea  South Korea         2.0         1.0
#
#       tournament       city      country  neutral       Winner
# 17467   Friendly  Pyongyang  North Korea    False  North Korea

# %%
pd.set_option('display.max_rows', 40)
dfgol = pd.read_csv('df_ResultadosSeleções/goalscorers.csv')
dfgol
# Out:
#              date  home_team away_team       team              scorer  minute  \
# 0      1916-07-02      Chile   Uruguay    Uruguay     José Piendibene    44.0
# 1      1916-07-02      Chile   Uruguay    Uruguay    Isabelino Gradín    55.0
# 2      1916-07-02      Chile   Uruguay    Uruguay    Isabelino Gradín    70.0
# 3      1916-07-02      Chile   Uruguay    Uruguay     José Piendibene    75.0
# 4      1916-07-06  Argentina     Chile  Argentina       Alberto Ohaco     2.0
# ...           ...        ...       ...        ...                 ...     ...
# 44114  2024-03-21      Wales   Finland      Wales     Brennan Johnson    47.0
# 44115  2024-03-21      Wales   Finland      Wales        Daniel James    86.0
# 44116  2024-03-26    Ukraine   Iceland    Iceland  Albert Guðmundsson    30.0
# 44117  2024-03-26    Ukraine   Iceland    Ukraine    Viktor Tsyhankov    54.0
# 44118  2024-03-26    Ukraine   Iceland    Ukraine     Mykhailo Mudryk    84.0
#
#        own_goal  penalty
# ...

# %%
dfgol.loc[
    dfgol['date'] == "1990-10-11"
]
# Out:
# Empty DataFrame
# Columns: [date, home_team, away_team, team, scorer, minute, own_goal, penalty]
# Index: []

# %%
df['chave'] = (df['date'] + df['home_team'] + df['away_team'])
dfgol['chave'] = (dfgol['date'] + dfgol['home_team'] + dfgol['away_team'])
print(df)
# Out:
#              date home_team away_team  home_score  away_score tournament  \
# 0      1872-11-30  Scotland   England         0.0         0.0   Friendly
# 1      1873-03-08   England  Scotland         4.0         2.0   Friendly
# 2      1874-03-07  Scotland   England         2.0         1.0   Friendly
# 3      1875-03-06   England  Scotland         2.0         2.0   Friendly
# 4      1876-03-04  Scotland   England         3.0         0.0   Friendly
# ...           ...       ...       ...         ...         ...        ...
# 47121  2024-07-06       NaN       NaN         NaN         NaN  UEFA Euro
# 47122  2024-07-06       NaN       NaN         NaN         NaN  UEFA Euro
# 47123  2024-07-09       NaN       NaN         NaN         NaN  UEFA Euro
# 47124  2024-07-10       NaN       NaN         NaN         NaN  UEFA Euro
# 47125  2024-07-14       NaN       NaN         NaN         NaN  UEFA Euro
#
#              city   country  neutral    Winner                      chave
# ...

# %%
dfgol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44119 entries, 0 to 44118
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       44119 non-null  object
#  1   home_team  44119 non-null  object
#  2   away_team  44119 non-null  object
#  3   team       44119 non-null  object
#  4   scorer     44070 non-null  object
#  5   minute     43860 non-null  float64
#  6   own_goal   44119 non-null  bool
#  7   penalty    44119 non-null  bool
#  8   chave      44119 non-null  object
# dtypes: bool(2), float64(1), object(6)
# memory usage: 2.4+ MB

# %%
dfjoin = df.merge(dfgol, on='chave', how='left')
dfjoin
# Out:
#            date_x home_team_x away_team_x  home_score  away_score tournament  \
# 0      1872-11-30    Scotland     England         0.0         0.0   Friendly
# 1      1873-03-08     England    Scotland         4.0         2.0   Friendly
# 2      1874-03-07    Scotland     England         2.0         1.0   Friendly
# 3      1875-03-06     England    Scotland         2.0         2.0   Friendly
# 4      1876-03-04    Scotland     England         3.0         0.0   Friendly
# ...           ...         ...         ...         ...         ...        ...
# 76953  2024-07-06         NaN         NaN         NaN         NaN  UEFA Euro
# 76954  2024-07-06         NaN         NaN         NaN         NaN  UEFA Euro
# 76955  2024-07-09         NaN         NaN         NaN         NaN  UEFA Euro
# 76956  2024-07-10         NaN         NaN         NaN         NaN  UEFA Euro
# 76957  2024-07-14         NaN         NaN         NaN         NaN  UEFA Euro
#
# ...

# %%
dfbrxar = dfjoin.loc[
    ((dfjoin['home_team_x'] == "Brazil") & (dfjoin['away_team_x'] == "Argentina")) | 
    ((dfjoin['home_team_x'] == "Argentina") & (dfjoin['away_team_x'] == "Brazil"))
]

dfbrxar['scorer'].value_counts()
# Out:
# scorer
# Norberto Doroteo Méndez    5
# Ronaldo                    4
# Manuel Seoane              4
# José Sanfilippo            3
# Adriano                    3
#                           ..
# Raúl Armando Savoy         1
# Mario Rodríguez            1
# Geraldo José da Silva      1
# Omar Higinio García        1
# Ángel Di María             1
# Name: count, Length: 97, dtype: int64

# %%
pd.set_option('display.max_rows', None)
dfbrxar
# Out:
#            date_x home_team_x away_team_x  home_score  away_score  \
# 432    1914-09-20   Argentina      Brazil         3.0         0.0
# 433    1914-09-27   Argentina      Brazil         0.0         1.0
# 476    1916-07-10   Argentina      Brazil         1.0         1.0
# 477    1916-07-10   Argentina      Brazil         1.0         1.0
# 515    1917-10-03   Argentina      Brazil         4.0         2.0
# 516    1917-10-03   Argentina      Brazil         4.0         2.0
# 517    1917-10-03   Argentina      Brazil         4.0         2.0
# 518    1917-10-03   Argentina      Brazil         4.0         2.0
# 519    1917-10-03   Argentina      Brazil         4.0         2.0
# 520    1917-10-03   Argentina      Brazil         4.0         2.0
# 577    1919-05-18      Brazil   Argentina         3.0         1.0
# 578    1919-05-18      Brazil   Argentina         3.0         1.0
# 579    1919-05-18      Brazil   Argentina         3.0         1.0
# ...
